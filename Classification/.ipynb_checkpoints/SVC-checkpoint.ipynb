# %% [markdown]
# # Classification Part A — Support Vector Classifier (SVC)
#
# ## Problem Statement
#
# Predict the customer review score using order, product, geographic,
# and engineered features from the e-commerce dataset.
#
# ### Algorithm
# Support Vector Classifier (SVC)
#
# ### Evaluation Metrics
# - Accuracy
# - Precision
# - Recall
# - Weighted F1-Score
# - Confusion Matrix
# - ROC-AUC (One-vs-Rest)

# %%
import numpy as np
import pandas as pd

from sklearn.svm import SVC

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = np.load("classification_data.npz")

X_train = data["X_train"]
X_test = data["X_test"]
y_train = data["y_train"]
y_test = data["y_test"]

feature_names = pd.read_csv(
    "classification_feature_names.csv",
    header=None
)[0].to_numpy()

print("X_train shape:", X_train.shape)
print("X_test shape :", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape :", y_test.shape)
print("Number of features:", len(feature_names))
# Out:
# X_train shape: (17044, 125)
# X_test shape : (4262, 125)
# y_train shape: (17044,)
# y_test shape : (4262,)
# Number of features: 125

# %% [markdown]
# ## Support Vector Classifier Model
#
# A Support Vector Classifier (SVC) finds a decision boundary that separates
# different classes by maximizing the margin between them. The input features
# have already been standardized during preprocessing.

# %%
svc_model = SVC(
    kernel="linear",
    probability=True,
    random_state=42
)

print(svc_model)
# Out:
# SVC(kernel='linear', probability=True, random_state=42)

# %% [markdown]
# ### Model Training
#
# The SVC model is trained using the prepared training dataset. The test dataset remains unseen during training and is used only for final evaluation.

# %%
svc_model.fit(X_train, y_train)

print("SVC model trained successfully.")
# Out:
# SVC model trained successfully.

# %% [markdown]
# ### Predictions
#
# The trained SVC model is used to generate predictions for both the training and
# unseen test datasets. The test predictions will be used for the final model
# evaluation.

# %%
y_train_pred = svc_model.predict(X_train)
y_test_pred = svc_model.predict(X_test)

print("Training predictions generated:", len(y_train_pred))
print("Test predictions generated:", len(y_test_pred))
# Out:
# Training predictions generated: 17044
# Test predictions generated: 4262

# %% [markdown]
# ## Model Evaluation
#
# The SVC model is evaluated on the unseen test set using accuracy, weighted
# precision, weighted recall, and weighted F1-score. Weighted averaging is used
# because the review-score classes are not perfectly balanced.

# %%
accuracy = accuracy_score(y_test, y_test_pred)

precision = precision_score(
    y_test,
    y_test_pred,
    average="weighted"
)

recall = recall_score(
    y_test,
    y_test_pred,
    average="weighted"
)

f1 = f1_score(
    y_test,
    y_test_pred,
    average="weighted"
)

roc_auc = roc_auc_score(
    y_test,
    svc_model.predict_proba(X_test),
    multi_class="ovr",
    average="weighted"
)

print("Accuracy       :", accuracy)
print("Precision      :", precision)
print("Recall         :", recall)
print("Weighted F1    :", f1)
print("ROC-AUC (OvR)  :", roc_auc)
# Out:
# Accuracy       : 0.339277334584702
# Precision      : 0.3168375946402234
# Recall         : 0.339277334584702
# Weighted F1    : 0.24670377726796117
# ROC-AUC (OvR)  : 0.5896672945054109

# %% [markdown]
# ## Confusion Matrix and Classification Report
#
# The confusion matrix shows the distribution of correct and incorrect
# predictions across the five review-score classes. The classification report
# provides precision, recall, and F1-score for each class.

# %%
cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(7, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Score 1", "Score 2", "Score 3", "Score 4", "Score 5"],
    yticklabels=["Score 1", "Score 2", "Score 3", "Score 4", "Score 5"]
)

plt.title("Confusion Matrix — Support Vector Classifier")
plt.xlabel("Predicted Review Score")
plt.ylabel("Actual Review Score")
plt.tight_layout()
plt.show()

print("\nClassification Report:\n")

print(
    classification_report(
        y_test,
        y_test_pred,
        target_names=[
            "Score 1",
            "Score 2",
            "Score 3",
            "Score 4",
            "Score 5"
        ],
        zero_division=0
    )
)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      Score 1       0.70      0.12      0.20       390
#      Score 2       0.20      0.01      0.01       722
#      Score 3       0.32      0.50      0.39      1106
#      Score 4       0.21      0.01      0.03      1003
#      Score 5       0.35      0.79      0.48      1041
#
#     accuracy                           0.34      4262
#    macro avg       0.36      0.29      0.22      4262
# weighted avg       0.32      0.34      0.25      4262

# %% [markdown]
# ### Observation
#
# The Support Vector Classifier performs well in identifying Score 3 and Score 5,
# with recall values of 0.50 and 0.79 respectively. Score 1 has high precision
# (0.70) but low recall (0.12), indicating that the model is selective when
# predicting this class. Scores 2 and 4 have very low recall (0.01), showing
# that the model has difficulty identifying these classes. Although the model
# achieves an accuracy of 0.34, its weighted F1-score is lower at 0.25, which
# indicates uneven performance across the review-score classes.

# %%
svc_results = {
    "Model": "Support Vector Classifier",
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "Weighted F1": f1,
    "ROC-AUC": roc_auc
}

svc_results
# Out:
# {'Model': 'Support Vector Classifier',
#  'Accuracy': 0.339277334584702,
#  'Precision': 0.3168375946402234,
#  'Recall': 0.339277334584702,
#  'Weighted F1': 0.24670377726796117,
#  'ROC-AUC': 0.5896672945054109}
